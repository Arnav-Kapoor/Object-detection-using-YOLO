# %%
from ultralytics import YOLO
import cv2

# %%
model=YOLO('./YOLO weights/yolov8n.pt')

# %%
import math

cap=cv2.VideoCapture('.\images\car_moving.mp4')

while True:
    ret,img=cap.read()
    img=cv2.resize(img,(640,360))
    results=model(img, stream=True)
    
    for r in results:
        boxes=r.boxes
        for box in boxes:
            x1,y1,x2,y2=box.xyxy[0] #xywh can also be used
            x1,y1,x2,y2=int(x1),int(y1),int(x2),int(y2)
            
            
            conf=math.ceil(box.conf[0]*100)/100
            classs=int(box.cls[0])
            if classs==2 and conf>0.4:
                cv2.rectangle(img,(x1,y1),(x2,y2),(255,0,255),3)
                # cv2.rectangle(img,(max(0,x1),max(40,y1)),(x1+200,y1-30),(0,255,255),cv2.FILLED)
                cv2.putText(img,f'{conf} class No.:{classs}',(max(0,x1),max(40,y1)),cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,255),2)
            
            
    cv2.imshow("Img",img)
    if cv2.waitKey(1) & 0xFF==ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 3 cars, 100.3ms
# Speed: 0.0ms pre-process, 100.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 cars, 112.0ms
# Speed: 1.0ms pre-process, 112.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 cars, 110.3ms
# Speed: 1.4ms pre-process, 110.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 cars, 120.9ms
# Speed: 0.0ms pre-process, 120.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 cars, 108.0ms
# Speed: 2.0ms pre-process, 108.0ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 cars, 111.8ms
# Speed: 0.0ms pre-process, 111.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 cars, 108.3ms
# Speed: 0.0ms pre-process, 108.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 108.9ms
# ...
